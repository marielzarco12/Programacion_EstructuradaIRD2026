# %% [markdown]
# # operaciones
#
# en esta area se realizan las operaciones aritmeticas "basicas" - "soy el primero"

# %%
suma = 4 + 2
resta = 4 - 2
div = 4 / 2
multi = 4 * 2
divEntera = 10//3
mod = 10 % 2
potencia = 10 ** 2

# %% [markdown]
# ## Generar salida
# Mediate la utilizacion de un string litera se construye la salida
#
# ``` python
# numero = 10
# salida = f"salida de una sola linea {numero = 10}"
#
# salida = f"""
#         salida de variables lineas {numero}
# ```

# %%
salida = f"""===== resultado de operadores aritmeticos
    La suma es: {suma}
    la resta es: {resta}
    la multiplicacion es: {multi}
    la division es: {div}
    la division entera es: {divEntera}
    el modulo es: {mod}
    la potencia es: {potencia}
    """
print (salida)
# Out:
# ===== resultado de operadores aritmeticos
#     La suma es: 6
#     la resta es: 2
#     la multiplicacion es: 8
#     la division es: 2.0
#     la division entera es: 3
#     el modulo es: 0
#     la potencia es: 100
